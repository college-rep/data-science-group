# %%
from datetime import date

import numpy as np
import pandas as pd
import yaml
from sqlalchemy import create_engine

# %% [markdown]
# # database connections

# %%
with open('../config.yml', 'r') as f:
    config = yaml.safe_load(f)
    config_co = config['CO_SA']
    config_etl = config['ETL_PRO']

url_co = (f"{config_co['drivername']}://{config_co['user']}:{config_co['password']}@{config_co['host']}:"
          f"{config_co['port']}/{config_co['dbname']}")
url_etl = (f"{config_etl['drivername']}://{config_etl['user']}:{config_etl['password']}@{config_etl['host']}:"
           f"{config_etl['port']}/{config_etl['dbname']}")
co_sa = create_engine(url_co)
etl_conn = create_engine(url_etl)

# %% [markdown]
# # Extract
#
# Sede no trae el nombre del departamento directo, se necesita el join `sede -> ciudad -> departamento`.

# %%
dim_sede = pd.read_sql_query('''
    SELECT
        s.sede_id,
        s.nombre   AS nombre_sede,
        s.direccion,
        c.nombre   AS ciudad,
        d.nombre   AS departamento,
        s.cliente_id
    FROM sede s
    LEFT JOIN ciudad c       ON s.ciudad_id = c.ciudad_id
    LEFT JOIN departamento d ON c.departamento_id = d.departamento_id
''', co_sa)
dim_sede.info()
dim_sede
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sede_id       52 non-null     int64
#  1   nombre_sede   52 non-null     str
#  2   direccion     52 non-null     str
#  3   ciudad        52 non-null     str
#  4   departamento  52 non-null     str
#  5   cliente_id    52 non-null     int64
# dtypes: int64(2), str(4)
# memory usage: 2.6 KB
#     sede_id                       nombre_sede                    direccion  \
# 0        10                   FARALLONES /123  Los angeles distrito Latino
# 1        11                     REMEDIOZ/ 123  Los angeles distrito Latino
# 2        13                  DIME / LOS ROJOS  Los angeles distrito Latino
# 3        14             DESPACHOS / LOS ROJOS  Los angeles distrito Latino
# 4        23             POPAYAN BODEGA 28 / A  Los angeles distrito Latino
# 5        24                  PASTO VITRINA /   Los angeles distrito Latino
# 6        25                  PASTO BODEGA 29/  Los angeles distrito Latino
# 7        26            PALMIRA BODEGA 20  /    Los angeles distrito Latino
# 8        32                   CLINICA FABILUX  Los angeles distrito Latino
# 9        33                FORDES PASOANCHOS   Los angeles distrito Latino
# 10       35                            JMC /   Los angeles distrito Latino
# 11       46                     SAN BER NANDO  Los angeles distrito Latino
# 12       44                       VALLE NORTE  Los angeles distrito Latino
# 13       45                          CAMBULOS  Los angeles distrito Latino
# 14        1         Sede principal - Cliente1  Los angeles distrito Latino
# 15        2              sede aux - cliente 1  Los angeles distrito Latino
# 16        5                      VASQUEZ COBO  Los angeles distrito Latino
# 17        7                     VILLACOLOMBIA  Los angeles distrito Latino
# 18        9                 PRINCIPAL/ ESENSA  Los angeles distrito Latino
# 19        8             PRINCIPAL / OCCIDENTE  Los angeles distrito Latino
# 20       48              BATALLON DISPENSARIO  Los angeles distrito Latino
# 21       28             CONTRIBUTIVO / ESENSA  Los angeles distrito Latino
# 22       49                         OCCISALUD  Los angeles distrito Latino
# 23       40                    TRAUMA ORIENTE  Los angeles distrito Latino
# 24        6                         CAPITOLIO  Los angeles distrito Latino
# 25       41                         ARTMEDICA  Los angeles distrito Latino
# 26       42                      CLINICA CALI  Los angeles distrito Latino
# 27       15  PRINCIPAL NORTE / CHINA PACIFICO  Los angeles distrito Latino
# 28       16       MEGATALLER / CHINA PACIFICO  Los angeles distrito Latino
# 29       17                BUSES Y CAMIONES -  Los angeles distrito Latino
# 30       18                            FORCAS  Los angeles distrito Latino
# 31       19                         HYUNDAI /  Los angeles distrito Latino
# 32       20                FORD CAÑAS FLASCAS  Los angeles distrito Latino
# 33       21                    BUGA BODEGA 24  Los angeles distrito Latino
# 34       22                 TULUA BODEGA 26 /  Los angeles distrito Latino
# 35       29          PROVIDA ATENCION BASICA   Los angeles distrito Latino
# 36       34                         AUTOPISTA  Los angeles distrito Latino
# 37       36                     PRINCIPAL /14  Los angeles distrito Latino
# 38       37                             HEMAS  Los angeles distrito Latino
# 39       47                      CLINICA CALI  Los angeles distrito Latino
# 40       51                         CLUB NOEL  Los angeles distrito Latino
# 41       30                 RIOCAUCA / ESENSA  Los angeles distrito Latino
# 42       50                         RECUPERAR  Los angeles distrito Latino
# 43       38                          HEMOLIFE  Los angeles distrito Latino
# 44       31                        CRISTO REY  Los angeles distrito Latino
# 45       52                      NUEVA HEMATO  Los angeles distrito Latino
# 46       53                      NUEVA HEMATO  Los angeles distrito Latino
# 47       54                      NUEVA HEMATO  Los angeles distrito Latino
# 48       85                             CIMEX  Los angeles distrito Latino
# 49        3               TORRES DE MARACAIBO  Los angeles distrito Latino
# 50        4                           INGENIO  Los angeles distrito Latino
# 51       12            PALMA REAL / LOS ROJOS  Los angeles distrito Latino
#
#      ciudad     departamento  cliente_id
# 0      CALI  VALLE DEL CAUCA           4
# 1      CALI  VALLE DEL CAUCA           4
# 2      CALI  VALLE DEL CAUCA           4
# 3      CALI  VALLE DEL CAUCA           4
# 4   POPAYAN            CAUCA          11
# 5     PASTO           NARIÑO          11
# 6     PASTO           NARIÑO          11
# 7   PALMIRA  VALLE DEL CAUCA          11
# 8      CALI  VALLE DEL CAUCA          12
# 9      CALI  VALLE DEL CAUCA          11
# 10     CALI  VALLE DEL CAUCA          11
# 11     CALI  VALLE DEL CAUCA          24
# 12     CALI  VALLE DEL CAUCA          25
# 13     CALI  VALLE DEL CAUCA          25
# 14     CALI  VALLE DEL CAUCA           2
# 15     CALI  VALLE DEL CAUCA           2
# 16     CALI  VALLE DEL CAUCA           5
# 17     CALI  VALLE DEL CAUCA           5
# 18     CALI  VALLE DEL CAUCA          10
# 19     CALI  VALLE DEL CAUCA           5
# 20     CALI  VALLE DEL CAUCA          12
# 21     CALI  VALLE DEL CAUCA          10
# 22     CALI  VALLE DEL CAUCA          26
# 23     CALI  VALLE DEL CAUCA           9
# 24     CALI  VALLE DEL CAUCA           5
# 25     CALI  VALLE DEL CAUCA          18
# 26     CALI  VALLE DEL CAUCA           7
# 27     CALI  VALLE DEL CAUCA          11
# 28     CALI  VALLE DEL CAUCA          11
# 29     CALI  VALLE DEL CAUCA          11
# 30     CALI  VALLE DEL CAUCA          11
# 31     CALI  VALLE DEL CAUCA          11
# 32     CALI  VALLE DEL CAUCA          11
# 33     BUGA  VALLE DEL CAUCA          11
# 34    TULUA  VALLE DEL CAUCA          11
# 35     CALI  VALLE DEL CAUCA          10
# 36     CALI  VALLE DEL CAUCA          11
# 37     CALI  VALLE DEL CAUCA           6
# 38     CALI  VALLE DEL CAUCA           8
# 39     CALI  VALLE DEL CAUCA           7
# 40     CALI  VALLE DEL CAUCA          22
# 41     CALI  VALLE DEL CAUCA          10
# 42     CALI  VALLE DEL CAUCA          15
# 43     CALI  VALLE DEL CAUCA           3
# 44     CALI  VALLE DEL CAUCA           7
# 45     CALI  VALLE DEL CAUCA           8
# 46     CALI  VALLE DEL CAUCA           8
# 47     CALI  VALLE DEL CAUCA           8
# 48     CALI  VALLE DEL CAUCA          27
# 49     CALI  VALLE DEL CAUCA           5
# 50     CALI  VALLE DEL CAUCA           5
# 51  PALMIRA  VALLE DEL CAUCA           4

# %% [markdown]
# # Transformations
#
# Los `LEFT JOIN` pueden dejar `ciudad` o `departamento` en nulo cuando la sede no tiene la referencia completa; se normalizan esos vacios. `cliente_id` se conserva como atributo extra para responder la pregunta de sedes por cliente.

# %%
dim_sede.replace({np.nan: 'no aplica', ' ': 'no aplica', '': 'no aplica'}, inplace=True)
dim_sede['saved'] = date.today()
dim_sede
# Out:
#     sede_id                       nombre_sede                    direccion  \
# 0        10                   FARALLONES /123  Los angeles distrito Latino
# 1        11                     REMEDIOZ/ 123  Los angeles distrito Latino
# 2        13                  DIME / LOS ROJOS  Los angeles distrito Latino
# 3        14             DESPACHOS / LOS ROJOS  Los angeles distrito Latino
# 4        23             POPAYAN BODEGA 28 / A  Los angeles distrito Latino
# 5        24                  PASTO VITRINA /   Los angeles distrito Latino
# 6        25                  PASTO BODEGA 29/  Los angeles distrito Latino
# 7        26            PALMIRA BODEGA 20  /    Los angeles distrito Latino
# 8        32                   CLINICA FABILUX  Los angeles distrito Latino
# 9        33                FORDES PASOANCHOS   Los angeles distrito Latino
# 10       35                            JMC /   Los angeles distrito Latino
# 11       46                     SAN BER NANDO  Los angeles distrito Latino
# 12       44                       VALLE NORTE  Los angeles distrito Latino
# 13       45                          CAMBULOS  Los angeles distrito Latino
# 14        1         Sede principal - Cliente1  Los angeles distrito Latino
# 15        2              sede aux - cliente 1  Los angeles distrito Latino
# 16        5                      VASQUEZ COBO  Los angeles distrito Latino
# 17        7                     VILLACOLOMBIA  Los angeles distrito Latino
# 18        9                 PRINCIPAL/ ESENSA  Los angeles distrito Latino
# 19        8             PRINCIPAL / OCCIDENTE  Los angeles distrito Latino
# 20       48              BATALLON DISPENSARIO  Los angeles distrito Latino
# 21       28             CONTRIBUTIVO / ESENSA  Los angeles distrito Latino
# 22       49                         OCCISALUD  Los angeles distrito Latino
# 23       40                    TRAUMA ORIENTE  Los angeles distrito Latino
# 24        6                         CAPITOLIO  Los angeles distrito Latino
# 25       41                         ARTMEDICA  Los angeles distrito Latino
# 26       42                      CLINICA CALI  Los angeles distrito Latino
# 27       15  PRINCIPAL NORTE / CHINA PACIFICO  Los angeles distrito Latino
# 28       16       MEGATALLER / CHINA PACIFICO  Los angeles distrito Latino
# 29       17                BUSES Y CAMIONES -  Los angeles distrito Latino
# 30       18                            FORCAS  Los angeles distrito Latino
# 31       19                         HYUNDAI /  Los angeles distrito Latino
# 32       20                FORD CAÑAS FLASCAS  Los angeles distrito Latino
# 33       21                    BUGA BODEGA 24  Los angeles distrito Latino
# 34       22                 TULUA BODEGA 26 /  Los angeles distrito Latino
# 35       29          PROVIDA ATENCION BASICA   Los angeles distrito Latino
# 36       34                         AUTOPISTA  Los angeles distrito Latino
# 37       36                     PRINCIPAL /14  Los angeles distrito Latino
# 38       37                             HEMAS  Los angeles distrito Latino
# 39       47                      CLINICA CALI  Los angeles distrito Latino
# 40       51                         CLUB NOEL  Los angeles distrito Latino
# 41       30                 RIOCAUCA / ESENSA  Los angeles distrito Latino
# 42       50                         RECUPERAR  Los angeles distrito Latino
# 43       38                          HEMOLIFE  Los angeles distrito Latino
# 44       31                        CRISTO REY  Los angeles distrito Latino
# 45       52                      NUEVA HEMATO  Los angeles distrito Latino
# 46       53                      NUEVA HEMATO  Los angeles distrito Latino
# 47       54                      NUEVA HEMATO  Los angeles distrito Latino
# 48       85                             CIMEX  Los angeles distrito Latino
# 49        3               TORRES DE MARACAIBO  Los angeles distrito Latino
# 50        4                           INGENIO  Los angeles distrito Latino
# 51       12            PALMA REAL / LOS ROJOS  Los angeles distrito Latino
#
#      ciudad     departamento  cliente_id       saved
# 0      CALI  VALLE DEL CAUCA           4  2026-06-27
# 1      CALI  VALLE DEL CAUCA           4  2026-06-27
# 2      CALI  VALLE DEL CAUCA           4  2026-06-27
# 3      CALI  VALLE DEL CAUCA           4  2026-06-27
# 4   POPAYAN            CAUCA          11  2026-06-27
# 5     PASTO           NARIÑO          11  2026-06-27
# 6     PASTO           NARIÑO          11  2026-06-27
# 7   PALMIRA  VALLE DEL CAUCA          11  2026-06-27
# 8      CALI  VALLE DEL CAUCA          12  2026-06-27
# 9      CALI  VALLE DEL CAUCA          11  2026-06-27
# 10     CALI  VALLE DEL CAUCA          11  2026-06-27
# 11     CALI  VALLE DEL CAUCA          24  2026-06-27
# 12     CALI  VALLE DEL CAUCA          25  2026-06-27
# 13     CALI  VALLE DEL CAUCA          25  2026-06-27
# 14     CALI  VALLE DEL CAUCA           2  2026-06-27
# 15     CALI  VALLE DEL CAUCA           2  2026-06-27
# 16     CALI  VALLE DEL CAUCA           5  2026-06-27
# 17     CALI  VALLE DEL CAUCA           5  2026-06-27
# 18     CALI  VALLE DEL CAUCA          10  2026-06-27
# 19     CALI  VALLE DEL CAUCA           5  2026-06-27
# 20     CALI  VALLE DEL CAUCA          12  2026-06-27
# 21     CALI  VALLE DEL CAUCA          10  2026-06-27
# 22     CALI  VALLE DEL CAUCA          26  2026-06-27
# 23     CALI  VALLE DEL CAUCA           9  2026-06-27
# 24     CALI  VALLE DEL CAUCA           5  2026-06-27
# 25     CALI  VALLE DEL CAUCA          18  2026-06-27
# 26     CALI  VALLE DEL CAUCA           7  2026-06-27
# 27     CALI  VALLE DEL CAUCA          11  2026-06-27
# 28     CALI  VALLE DEL CAUCA          11  2026-06-27
# 29     CALI  VALLE DEL CAUCA          11  2026-06-27
# 30     CALI  VALLE DEL CAUCA          11  2026-06-27
# 31     CALI  VALLE DEL CAUCA          11  2026-06-27
# 32     CALI  VALLE DEL CAUCA          11  2026-06-27
# 33     BUGA  VALLE DEL CAUCA          11  2026-06-27
# 34    TULUA  VALLE DEL CAUCA          11  2026-06-27
# 35     CALI  VALLE DEL CAUCA          10  2026-06-27
# 36     CALI  VALLE DEL CAUCA          11  2026-06-27
# 37     CALI  VALLE DEL CAUCA           6  2026-06-27
# 38     CALI  VALLE DEL CAUCA           8  2026-06-27
# 39     CALI  VALLE DEL CAUCA           7  2026-06-27
# 40     CALI  VALLE DEL CAUCA          22  2026-06-27
# 41     CALI  VALLE DEL CAUCA          10  2026-06-27
# 42     CALI  VALLE DEL CAUCA          15  2026-06-27
# 43     CALI  VALLE DEL CAUCA           3  2026-06-27
# 44     CALI  VALLE DEL CAUCA           7  2026-06-27
# 45     CALI  VALLE DEL CAUCA           8  2026-06-27
# 46     CALI  VALLE DEL CAUCA           8  2026-06-27
# 47     CALI  VALLE DEL CAUCA           8  2026-06-27
# 48     CALI  VALLE DEL CAUCA          27  2026-06-27
# 49     CALI  VALLE DEL CAUCA           5  2026-06-27
# 50     CALI  VALLE DEL CAUCA           5  2026-06-27
# 51  PALMIRA  VALLE DEL CAUCA           4  2026-06-27

# %% [markdown]
# # Alinear nombres de columnas al diagrama
# ID_Sede (PK) -> indice al cargar | Nombre_Sede | Direccion | Ciudad | Departamento
#
# `cliente_id` no esta en el diagrama, se deja como atributo extra y no estorba.

# %%
dim_sede.rename(columns={
    'sede_id': 'id_sede',
    'cliente_id': 'id_cliente',
}, inplace=True)
dim_sede
# Out:
#     id_sede                       nombre_sede                    direccion  \
# 0        10                   FARALLONES /123  Los angeles distrito Latino
# 1        11                     REMEDIOZ/ 123  Los angeles distrito Latino
# 2        13                  DIME / LOS ROJOS  Los angeles distrito Latino
# 3        14             DESPACHOS / LOS ROJOS  Los angeles distrito Latino
# 4        23             POPAYAN BODEGA 28 / A  Los angeles distrito Latino
# 5        24                  PASTO VITRINA /   Los angeles distrito Latino
# 6        25                  PASTO BODEGA 29/  Los angeles distrito Latino
# 7        26            PALMIRA BODEGA 20  /    Los angeles distrito Latino
# 8        32                   CLINICA FABILUX  Los angeles distrito Latino
# 9        33                FORDES PASOANCHOS   Los angeles distrito Latino
# 10       35                            JMC /   Los angeles distrito Latino
# 11       46                     SAN BER NANDO  Los angeles distrito Latino
# 12       44                       VALLE NORTE  Los angeles distrito Latino
# 13       45                          CAMBULOS  Los angeles distrito Latino
# 14        1         Sede principal - Cliente1  Los angeles distrito Latino
# 15        2              sede aux - cliente 1  Los angeles distrito Latino
# 16        5                      VASQUEZ COBO  Los angeles distrito Latino
# 17        7                     VILLACOLOMBIA  Los angeles distrito Latino
# 18        9                 PRINCIPAL/ ESENSA  Los angeles distrito Latino
# 19        8             PRINCIPAL / OCCIDENTE  Los angeles distrito Latino
# 20       48              BATALLON DISPENSARIO  Los angeles distrito Latino
# 21       28             CONTRIBUTIVO / ESENSA  Los angeles distrito Latino
# 22       49                         OCCISALUD  Los angeles distrito Latino
# 23       40                    TRAUMA ORIENTE  Los angeles distrito Latino
# 24        6                         CAPITOLIO  Los angeles distrito Latino
# 25       41                         ARTMEDICA  Los angeles distrito Latino
# 26       42                      CLINICA CALI  Los angeles distrito Latino
# 27       15  PRINCIPAL NORTE / CHINA PACIFICO  Los angeles distrito Latino
# 28       16       MEGATALLER / CHINA PACIFICO  Los angeles distrito Latino
# 29       17                BUSES Y CAMIONES -  Los angeles distrito Latino
# 30       18                            FORCAS  Los angeles distrito Latino
# 31       19                         HYUNDAI /  Los angeles distrito Latino
# 32       20                FORD CAÑAS FLASCAS  Los angeles distrito Latino
# 33       21                    BUGA BODEGA 24  Los angeles distrito Latino
# 34       22                 TULUA BODEGA 26 /  Los angeles distrito Latino
# 35       29          PROVIDA ATENCION BASICA   Los angeles distrito Latino
# 36       34                         AUTOPISTA  Los angeles distrito Latino
# 37       36                     PRINCIPAL /14  Los angeles distrito Latino
# 38       37                             HEMAS  Los angeles distrito Latino
# 39       47                      CLINICA CALI  Los angeles distrito Latino
# 40       51                         CLUB NOEL  Los angeles distrito Latino
# 41       30                 RIOCAUCA / ESENSA  Los angeles distrito Latino
# 42       50                         RECUPERAR  Los angeles distrito Latino
# 43       38                          HEMOLIFE  Los angeles distrito Latino
# 44       31                        CRISTO REY  Los angeles distrito Latino
# 45       52                      NUEVA HEMATO  Los angeles distrito Latino
# 46       53                      NUEVA HEMATO  Los angeles distrito Latino
# 47       54                      NUEVA HEMATO  Los angeles distrito Latino
# 48       85                             CIMEX  Los angeles distrito Latino
# 49        3               TORRES DE MARACAIBO  Los angeles distrito Latino
# 50        4                           INGENIO  Los angeles distrito Latino
# 51       12            PALMA REAL / LOS ROJOS  Los angeles distrito Latino
#
#      ciudad     departamento  id_cliente       saved
# 0      CALI  VALLE DEL CAUCA           4  2026-06-27
# 1      CALI  VALLE DEL CAUCA           4  2026-06-27
# 2      CALI  VALLE DEL CAUCA           4  2026-06-27
# 3      CALI  VALLE DEL CAUCA           4  2026-06-27
# 4   POPAYAN            CAUCA          11  2026-06-27
# 5     PASTO           NARIÑO          11  2026-06-27
# 6     PASTO           NARIÑO          11  2026-06-27
# 7   PALMIRA  VALLE DEL CAUCA          11  2026-06-27
# 8      CALI  VALLE DEL CAUCA          12  2026-06-27
# 9      CALI  VALLE DEL CAUCA          11  2026-06-27
# 10     CALI  VALLE DEL CAUCA          11  2026-06-27
# 11     CALI  VALLE DEL CAUCA          24  2026-06-27
# 12     CALI  VALLE DEL CAUCA          25  2026-06-27
# 13     CALI  VALLE DEL CAUCA          25  2026-06-27
# 14     CALI  VALLE DEL CAUCA           2  2026-06-27
# 15     CALI  VALLE DEL CAUCA           2  2026-06-27
# 16     CALI  VALLE DEL CAUCA           5  2026-06-27
# 17     CALI  VALLE DEL CAUCA           5  2026-06-27
# 18     CALI  VALLE DEL CAUCA          10  2026-06-27
# 19     CALI  VALLE DEL CAUCA           5  2026-06-27
# 20     CALI  VALLE DEL CAUCA          12  2026-06-27
# 21     CALI  VALLE DEL CAUCA          10  2026-06-27
# 22     CALI  VALLE DEL CAUCA          26  2026-06-27
# 23     CALI  VALLE DEL CAUCA           9  2026-06-27
# 24     CALI  VALLE DEL CAUCA           5  2026-06-27
# 25     CALI  VALLE DEL CAUCA          18  2026-06-27
# 26     CALI  VALLE DEL CAUCA           7  2026-06-27
# 27     CALI  VALLE DEL CAUCA          11  2026-06-27
# 28     CALI  VALLE DEL CAUCA          11  2026-06-27
# 29     CALI  VALLE DEL CAUCA          11  2026-06-27
# 30     CALI  VALLE DEL CAUCA          11  2026-06-27
# 31     CALI  VALLE DEL CAUCA          11  2026-06-27
# 32     CALI  VALLE DEL CAUCA          11  2026-06-27
# 33     BUGA  VALLE DEL CAUCA          11  2026-06-27
# 34    TULUA  VALLE DEL CAUCA          11  2026-06-27
# 35     CALI  VALLE DEL CAUCA          10  2026-06-27
# 36     CALI  VALLE DEL CAUCA          11  2026-06-27
# 37     CALI  VALLE DEL CAUCA           6  2026-06-27
# 38     CALI  VALLE DEL CAUCA           8  2026-06-27
# 39     CALI  VALLE DEL CAUCA           7  2026-06-27
# 40     CALI  VALLE DEL CAUCA          22  2026-06-27
# 41     CALI  VALLE DEL CAUCA          10  2026-06-27
# 42     CALI  VALLE DEL CAUCA          15  2026-06-27
# 43     CALI  VALLE DEL CAUCA           3  2026-06-27
# 44     CALI  VALLE DEL CAUCA           7  2026-06-27
# 45     CALI  VALLE DEL CAUCA           8  2026-06-27
# 46     CALI  VALLE DEL CAUCA           8  2026-06-27
# 47     CALI  VALLE DEL CAUCA           8  2026-06-27
# 48     CALI  VALLE DEL CAUCA          27  2026-06-27
# 49     CALI  VALLE DEL CAUCA           5  2026-06-27
# 50     CALI  VALLE DEL CAUCA           5  2026-06-27
# 51  PALMIRA  VALLE DEL CAUCA           4  2026-06-27

# %% [markdown]
# # load

# %%
# NOTA: if_exists='append' porque la tabla se crea por DDL (ver sqlscripts.yml) con su PK real.
# 'replace' borraria esa tabla y la reemplazaria sin restricciones. Antes de correr este notebook,
# asegurate que el DDL ya creo la tabla dim_sede (o ejecuta el script de sqlscripts.yml manualmente).
dim_sede.to_sql('dim_sede', etl_conn, if_exists='append', index_label='key_dim_sede')
# Out:
# 52
